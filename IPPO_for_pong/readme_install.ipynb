# %% [markdown]
# ## 设置conda不自动激活base环境
# conda config --set auto_activate_base false

# %% [markdown]
# # 安装基础依赖包
# pip install numpy>=2.2.4
# pip install torch>=2.6.0

# %% [markdown]
# # 安装pettingzoo
# pip install pettingzoo[all]
#
# ## 遇到问题安装下面
# sudo apt update
# sudo apt install build-essential
# sudo apt install build-essential python3-dev swig
# sudo apt install cmake
# ## 后在github上找到一个issue，成功安装multi-agent-ale-py==0.1.11
# https://github.com/Farama-Foundation/Multi-Agent-ALE/issues/22
# ```
# git clone --depth=1 https://github.com/Farama-Foundation/Multi-Agent-ALE.git
# cd ./Multi-Agent-ALE
# python setup.py install
#
# sudo apt install cmake swig zlib1g-dev
# ```

# %% [markdown]
# # 安装Atari环境
#
# pip install pygame>=2.6.1
# pip install ale-py[roms]
# pip install ale-py

# %%
## 测试环境

from pettingzoo.atari import pong_v3 # basketball_pong_v3
env = pong_v3.parallel_env(render_mode="human")
observations, infos = env.reset()

while env.agents:
    # this is where you would insert your policy
    actions = {agent: env.action_space(agent).sample() for agent in env.agents}

    observations, rewards, terminations, truncations, infos = env.step(actions)
env.close()
